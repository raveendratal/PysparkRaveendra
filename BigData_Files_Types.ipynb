# %%
spark.read.parquet
spark.read.orc
spark.read.format('avro').load("")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
emp_csv = spark.read.csv("/FileStore/tables/emp.csv",header=True,inferSchema=True)
dept_csv = spark.read.csv("/FileStore/tables/dept.csv",header=True,inferSchema=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(emp_csv)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls /FileStore/tables/bigdata/orc/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.read.format('orc').load("/FileStore/tables/bigdata/orc/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.read.text('dbfs:/FileStore/tables/bigdata/orc/_committed_4398548747148635428'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody></tbody></table></div>

# %%
# %fs ls /FileStore/tables/bigdata/orc/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
emp_csv.write.format("orc").mode('append').save('/FileStore/tables/bigdata/orc/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
emp_csv.write.format("avro").mode('overwrite').saveAsTable('emp_avro')


emp_csv.write.format("parquet").mode('overwrite').saveAsTable('emp_parquet')
emp_csv.write.format("orc").mode('overwrite').saveAsTable('emp_orc')
dept_csv.write.format("avro").mode('overwrite').saveAsTable('dept_avro')
dept_csv.write.format("parquet").mode('overwrite').saveAsTable('dept_parquet')
dept_csv.write.format("orc").mode('overwrite').saveAsTable('dept_orc')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from emp_orc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls /user/hive/warehouse/emp_orc/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.read.format('avro').load("dbfs:/user/hive/warehouse/emp_avro/part-00000-tid-8444160175180277945-41d828b6-2218-4c26-8952-b48589eded6c-4-1-c000.avro"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.read.parquet('dbfs:/user/hive/warehouse/emp_parquet/part-00000-tid-9002161795043672389-18246d0d-0433-4c6e-ae3b-2468174413b1-5-1-c000.snappy.parquet'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.read.orc('dbfs:/user/hive/warehouse/emp_orc/part-00000-tid-6093908903159333998-bd189716-4057-4965-91c9-f8dca1ce788c-6-1-c000.snappy.orc'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls /user/hive/warehouse/emp_avro/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select deptno from emp_orc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deptno</th></tr></thead><tbody><tr><td>20</td></tr><tr><td>30</td></tr><tr><td>30</td></tr><tr><td>20</td></tr><tr><td>30</td></tr><tr><td>30</td></tr><tr><td>10</td></tr><tr><td>20</td></tr><tr><td>10</td></tr><tr><td>30</td></tr><tr><td>20</td></tr><tr><td>30</td></tr><tr><td>20</td></tr><tr><td>10</td></tr><tr><td>80</td></tr></tbody></table></div>

# %%
# %fs ls /user/hive/warehouse/emp_orc/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.read.text("dbfs:/user/hive/warehouse/emp_avro/part-00000-tid-90629523546968461-29cfdd50-06b8-4238-aef4-98cab4b478d6-27-1-c000.avro"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# FORD6�%	�$�{MILLERn�</td></tr><tr><td>n1-82��x�SEKHARdoctor�y�</td></tr><tr><td>����!GܐS	�	�~`�*{O</td></tr></tbody></table></div>

# %%
display(spark.read.text("dbfs:/user/hive/warehouse/emp_parquet/part-00000-tid-4785450324845871119-99816172-1c0b-4615-8409-41b1267c5de4-28-1-c000.snappy.parquet"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.read.text("dbfs:/user/hive/warehouse/emp_orc/part-00000-tid-4180354349491276615-13d75309-e4d4-4aed-a71c-08fbc307db90-29-1-c000.snappy.orc"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ���"(�0��ORC</td></tr></tbody></table></div>

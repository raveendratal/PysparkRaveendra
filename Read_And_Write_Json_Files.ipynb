# %% [markdown]
# #### Reading & Writing Json Data and creating RDD and DataFrame from Json Data
# * Spark SQL can automatically infer the schema of a JSON dataset and load it as a DataFrame. This conversion can be done using SparkSession.read.json on a JSON file.
#
# * Note that the file that is offered as a json file is not a typical JSON file. Each line must contain a separate, self-contained valid JSON object. For more information, please see JSON Lines text format, also called newline-delimited JSON.
#
# * For a regular multi-line JSON file, set the multiLine parameter to True.

# %%
# %fs ls /FileStore/tables/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/1/</td><td>1/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/1.xml/</td><td>1.xml/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/2.xml/</td><td>2.xml/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/3.xml/</td><td>3.xml/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/4.xml/</td><td>4.xml/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/5xml/</td><td>5xml/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/cache.png</td><td>cache.png</td><td>135788</td></tr><tr><td>dbfs:/FileStore/tables/custom.log</td><td>custom.log</td><td>6268</td></tr><tr><td>dbfs:/FileStore/tables/custom2020-08-08-16-34-39.log</td><td>custom2020-08-08-16-34-39.log</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/custom2020-08-08-16-35-05.log</td><td>custom2020-08-08-16-35-05.log</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/customlog2020-08-08-16-35-26.log</td><td>customlog2020-08-08-16-35-26.log</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/dept.csv</td><td>dept.csv</td><td>100</td></tr><tr><td>dbfs:/FileStore/tables/dept.json</td><td>dept.json</td><td>295</td></tr><tr><td>dbfs:/FileStore/tables/dept__1_.json</td><td>dept__1_.json</td><td>127</td></tr><tr><td>dbfs:/FileStore/tables/dept_quotes.csv</td><td>dept_quotes.csv</td><td>130</td></tr><tr><td>dbfs:/FileStore/tables/emp-1.csv</td><td>emp-1.csv</td><td>684</td></tr><tr><td>dbfs:/FileStore/tables/emp-1.json</td><td>emp-1.json</td><td>2515</td></tr><tr><td>dbfs:/FileStore/tables/emp.csv</td><td>emp.csv</td><td>684</td></tr><tr><td>dbfs:/FileStore/tables/emp.json</td><td>emp.json</td><td>2515</td></tr><tr><td>dbfs:/FileStore/tables/emp.xml</td><td>emp.xml</td><td>3732</td></tr><tr><td>dbfs:/FileStore/tables/emp.zip</td><td>emp.zip</td><td>2144903</td></tr><tr><td>dbfs:/FileStore/tables/emp__1_.json</td><td>emp__1_.json</td><td>865</td></tr><tr><td>dbfs:/FileStore/tables/emp_json.json/</td><td>emp_json.json/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/emp_xml.xml</td><td>emp_xml.xml</td><td>3207</td></tr><tr><td>dbfs:/FileStore/tables/excel</td><td>excel</td><td>4140</td></tr><tr><td>dbfs:/FileStore/tables/excel.xlsx</td><td>excel.xlsx</td><td>3786</td></tr><tr><td>dbfs:/FileStore/tables/excelfiles</td><td>excelfiles</td><td>4186</td></tr><tr><td>dbfs:/FileStore/tables/latestemp.csv/</td><td>latestemp.csv/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/logging.log</td><td>logging.log</td><td>132</td></tr><tr><td>dbfs:/FileStore/tables/myexcel.xlsx</td><td>myexcel.xlsx</td><td>10317</td></tr><tr><td>dbfs:/FileStore/tables/persist.png</td><td>persist.png</td><td>280742</td></tr><tr><td>dbfs:/FileStore/tables/relatedQueries__6_.csv</td><td>relatedQueries__6_.csv</td><td>949</td></tr></tbody></table></div>

# %% [markdown]
# #### Reading Json File Data...

# %%
# A JSON dataset is pointed to by path.
# The path can be either a single text file or a directory storing text files
# Option Charset also you can use based on your data -- option("charset", "UTF-8")
emp_json=spark.read.json('/FileStore/tables/emp_json.json')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
emp_json.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- COMM: string (nullable = true)
# -- DEPTNO: string (nullable = true)
# -- EMPNO: string (nullable = true)
# -- ENAME: string (nullable = true)
# -- HIREDATE: string (nullable = true)
# -- JOB: string (nullable = true)
# -- MGR: string (nullable = true)
# -- SAL: string (nullable = true)
#
# </div>

# %%
emp_text=spark.read.text('/FileStore/tables/emp_json.json')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(emp_text)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>{"EMPNO":"7369","ENAME":"SMITH","JOB":"CLERK","MGR":"7902","HIREDATE":"17-12-80","SAL":"800","DEPTNO":"20"}</td></tr><tr><td>{"EMPNO":"7499","ENAME":"ALLEN","JOB":"SALESMAN","MGR":"7698","HIREDATE":"20-02-81","SAL":"1600","COMM":"300","DEPTNO":"30"}</td></tr><tr><td>{"EMPNO":"7521","ENAME":"WARD","JOB":"SALESMAN","MGR":"7698","HIREDATE":"22-02-81","SAL":"1250","COMM":"500","DEPTNO":"30"}</td></tr><tr><td>{"EMPNO":"7566","ENAME":"JONES","JOB":"MANAGER","MGR":"7839","HIREDATE":"02-04-81","SAL":"2975","DEPTNO":"20"}</td></tr><tr><td>{"EMPNO":"7654","ENAME":"MARTIN","JOB":"SALESMAN","MGR":"7698","HIREDATE":"28-09-81","SAL":"1250","COMM":"1400","DEPTNO":"30"}</td></tr><tr><td>{"EMPNO":"7698","ENAME":"SGR","JOB":"MANAGER","MGR":"7839","HIREDATE":"01-05-81","SAL":"2850","DEPTNO":"30"}</td></tr><tr><td>{"EMPNO":"7782","ENAME":"RAVI","JOB":"MANAGER","MGR":"7839","HIREDATE":"09-06-81","SAL":"2450","DEPTNO":"10"}</td></tr><tr><td>{"EMPNO":"7788","ENAME":"SCOTT","JOB":"ANALYST","MGR":"7566","HIREDATE":"19-04-87","SAL":"3000","DEPTNO":"20"}</td></tr><tr><td>{"EMPNO":"7839","ENAME":"KING","JOB":"PRESIDENT","HIREDATE":"17-11-81","SAL":"5000","DEPTNO":"10"}</td></tr><tr><td>{"EMPNO":"7844","ENAME":"TURNER","JOB":"SALESMAN","MGR":"7698","HIREDATE":"08-09-81","SAL":"1500","COMM":"0","DEPTNO":"30"}</td></tr><tr><td>{"EMPNO":"7876","ENAME":"ADAMS","JOB":"CLERK","MGR":"7788","HIREDATE":"23-05-87","SAL":"1100","DEPTNO":"20"}</td></tr><tr><td>{"EMPNO":"7900","ENAME":"JAMES","JOB":"CLERK","MGR":"7698","HIREDATE":"03-12-81","SAL":"950","DEPTNO":"30"}</td></tr><tr><td>{"EMPNO":"7902","ENAME":"FORD","JOB":"ANALYST","MGR":"7566","HIREDATE":"03-12-81","SAL":"3000","DEPTNO":"20"}</td></tr><tr><td>{"EMPNO":"7934","ENAME":"MILLER","JOB":"CLERK","MGR":"7782","HIREDATE":"23-01-82","SAL":"1300","DEPTNO":"10"}</td></tr><tr><td>{"EMPNO":"1234","ENAME":"SEKHAR","JOB":"doctor","MGR":"7777","SAL":"667","COMM":"78","DEPTNO":"80"}</td></tr></tbody></table></div>

# %%
display(emp_json)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COMM</th><th>DEPTNO</th><th>EMPNO</th><th>ENAME</th><th>HIREDATE</th><th>JOB</th><th>MGR</th><th>SAL</th></tr></thead><tbody><tr><td>null</td><td>20</td><td>7369</td><td>SMITH</td><td>17-12-80</td><td>CLERK</td><td>7902</td><td>800</td></tr><tr><td>300</td><td>30</td><td>7499</td><td>ALLEN</td><td>20-02-81</td><td>SALESMAN</td><td>7698</td><td>1600</td></tr><tr><td>500</td><td>30</td><td>7521</td><td>WARD</td><td>22-02-81</td><td>SALESMAN</td><td>7698</td><td>1250</td></tr><tr><td>null</td><td>20</td><td>7566</td><td>JONES</td><td>02-04-81</td><td>MANAGER</td><td>7839</td><td>2975</td></tr><tr><td>1400</td><td>30</td><td>7654</td><td>MARTIN</td><td>28-09-81</td><td>SALESMAN</td><td>7698</td><td>1250</td></tr><tr><td>null</td><td>30</td><td>7698</td><td>SGR</td><td>01-05-81</td><td>MANAGER</td><td>7839</td><td>2850</td></tr><tr><td>null</td><td>10</td><td>7782</td><td>RAVI</td><td>09-06-81</td><td>MANAGER</td><td>7839</td><td>2450</td></tr><tr><td>null</td><td>20</td><td>7788</td><td>SCOTT</td><td>19-04-87</td><td>ANALYST</td><td>7566</td><td>3000</td></tr><tr><td>null</td><td>10</td><td>7839</td><td>KING</td><td>17-11-81</td><td>PRESIDENT</td><td>null</td><td>5000</td></tr><tr><td>0</td><td>30</td><td>7844</td><td>TURNER</td><td>08-09-81</td><td>SALESMAN</td><td>7698</td><td>1500</td></tr><tr><td>null</td><td>20</td><td>7876</td><td>ADAMS</td><td>23-05-87</td><td>CLERK</td><td>7788</td><td>1100</td></tr><tr><td>null</td><td>30</td><td>7900</td><td>JAMES</td><td>03-12-81</td><td>CLERK</td><td>7698</td><td>950</td></tr><tr><td>null</td><td>20</td><td>7902</td><td>FORD</td><td>03-12-81</td><td>ANALYST</td><td>7566</td><td>3000</td></tr><tr><td>null</td><td>10</td><td>7934</td><td>MILLER</td><td>23-01-82</td><td>CLERK</td><td>7782</td><td>1300</td></tr><tr><td>78</td><td>80</td><td>1234</td><td>SEKHAR</td><td>null</td><td>doctor</td><td>7777</td><td>667</td></tr></tbody></table></div>

# %%
emp_json=spark.read.json('/FileStore/tables/emp_json.json/part-00000-tid-1549053766405469969-89a72372-3b50-41ad-9efa-00667fb0e6a4-112-1-c000.json')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(emp_json)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COMM</th><th>DEPTNO</th><th>EMPNO</th><th>ENAME</th><th>HIREDATE</th><th>JOB</th><th>MGR</th><th>SAL</th></tr></thead><tbody><tr><td>null</td><td>20</td><td>7369</td><td>SMITH</td><td>17-12-80</td><td>CLERK</td><td>7902</td><td>800</td></tr><tr><td>300</td><td>30</td><td>7499</td><td>ALLEN</td><td>20-02-81</td><td>SALESMAN</td><td>7698</td><td>1600</td></tr><tr><td>500</td><td>30</td><td>7521</td><td>WARD</td><td>22-02-81</td><td>SALESMAN</td><td>7698</td><td>1250</td></tr><tr><td>null</td><td>20</td><td>7566</td><td>JONES</td><td>02-04-81</td><td>MANAGER</td><td>7839</td><td>2975</td></tr><tr><td>1400</td><td>30</td><td>7654</td><td>MARTIN</td><td>28-09-81</td><td>SALESMAN</td><td>7698</td><td>1250</td></tr><tr><td>null</td><td>30</td><td>7698</td><td>SGR</td><td>01-05-81</td><td>MANAGER</td><td>7839</td><td>2850</td></tr><tr><td>null</td><td>10</td><td>7782</td><td>RAVI</td><td>09-06-81</td><td>MANAGER</td><td>7839</td><td>2450</td></tr><tr><td>null</td><td>20</td><td>7788</td><td>SCOTT</td><td>19-04-87</td><td>ANALYST</td><td>7566</td><td>3000</td></tr><tr><td>null</td><td>10</td><td>7839</td><td>KING</td><td>17-11-81</td><td>PRESIDENT</td><td>null</td><td>5000</td></tr><tr><td>0</td><td>30</td><td>7844</td><td>TURNER</td><td>08-09-81</td><td>SALESMAN</td><td>7698</td><td>1500</td></tr><tr><td>null</td><td>20</td><td>7876</td><td>ADAMS</td><td>23-05-87</td><td>CLERK</td><td>7788</td><td>1100</td></tr><tr><td>null</td><td>30</td><td>7900</td><td>JAMES</td><td>03-12-81</td><td>CLERK</td><td>7698</td><td>950</td></tr><tr><td>null</td><td>20</td><td>7902</td><td>FORD</td><td>03-12-81</td><td>ANALYST</td><td>7566</td><td>3000</td></tr><tr><td>null</td><td>10</td><td>7934</td><td>MILLER</td><td>23-01-82</td><td>CLERK</td><td>7782</td><td>1300</td></tr><tr><td>78</td><td>80</td><td>1234</td><td>SEKHAR</td><td>null</td><td>doctor</td><td>7777</td><td>667</td></tr></tbody></table></div>

# %%
# %fs
ls /FileStore/tables/emp_json.json/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/emp_json.json/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/emp_json.json/_committed_1549053766405469969</td><td>_committed_1549053766405469969</td><td>114</td></tr><tr><td>dbfs:/FileStore/tables/emp_json.json/_started_1549053766405469969</td><td>_started_1549053766405469969</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/emp_json.json/part-00000-tid-1549053766405469969-89a72372-3b50-41ad-9efa-00667fb0e6a4-112-1-c000.json</td><td>part-00000-tid-1549053766405469969-89a72372-3b50-41ad-9efa-00667fb0e6a4-112-1-c000.json</td><td>1685</td></tr></tbody></table></div>

# %% [markdown]
# * creating sample json file using `dbutils.fs.put`

# %%
dbutils.fs.put("/tmp/test.json", """
{"string":"string1","int":1,"array":[1,2,3],"dict": {"key": "value1"}}
{"string":"string2","int":2,"array":[2,4,6],"dict": {"key": "value2"}}
{"string":"string3","int":3,"array":[3,6,9],"dict": {"key": "value3", "extra_key": "extra_value3"}}
""",True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 243 bytes.
# Out[13]: True</div>

# %%
# %fs
ls /tmp/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/tmp/LoanStats3a.csv</td><td>LoanStats3a.csv</td><td>42408085</td></tr><tr><td>dbfs:/tmp/PySpark_Data/</td><td>PySpark_Data/</td><td>0</td></tr><tr><td>dbfs:/tmp/book.xml</td><td>book.xml</td><td>5542</td></tr><tr><td>dbfs:/tmp/books.xml</td><td>books.xml</td><td>79</td></tr><tr><td>dbfs:/tmp/custom_log/</td><td>custom_log/</td><td>0</td></tr><tr><td>dbfs:/tmp/delta-table/</td><td>delta-table/</td><td>0</td></tr><tr><td>dbfs:/tmp/diamons.csv/</td><td>diamons.csv/</td><td>0</td></tr><tr><td>dbfs:/tmp/excel.xlsx</td><td>excel.xlsx</td><td>5269</td></tr><tr><td>dbfs:/tmp/file.csv/</td><td>file.csv/</td><td>0</td></tr><tr><td>dbfs:/tmp/files.csv/</td><td>files.csv/</td><td>0</td></tr><tr><td>dbfs:/tmp/hive/</td><td>hive/</td><td>0</td></tr><tr><td>dbfs:/tmp/loans_delta/</td><td>loans_delta/</td><td>0</td></tr><tr><td>dbfs:/tmp/multiline.json</td><td>multiline.json</td><td>386</td></tr><tr><td>dbfs:/tmp/myfile</td><td>myfile</td><td>74889749</td></tr><tr><td>dbfs:/tmp/sais_eu_19_demo/</td><td>sais_eu_19_demo/</td><td>0</td></tr><tr><td>dbfs:/tmp/test.json</td><td>test.json</td><td>243</td></tr><tr><td>dbfs:/tmp/test_dbfs.txt</td><td>test_dbfs.txt</td><td>40</td></tr></tbody></table></div>

# %%
test_df=spark.read.json('/tmp/test.json')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- array: array (nullable = true)
#     |-- element: long (containsNull = true)
# -- dict: struct (nullable = true)
#     |-- extra_key: string (nullable = true)
#     |-- key: string (nullable = true)
# -- int: long (nullable = true)
# -- string: string (nullable = true)
#
# </div>

# %%
display(test_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>array</th><th>dict</th><th>int</th><th>string</th></tr></thead><tbody><tr><td>List(1, 2, 3)</td><td>List(null, value1)</td><td>1</td><td>string1</td></tr><tr><td>List(2, 4, 6)</td><td>List(null, value2)</td><td>2</td><td>string2</td></tr><tr><td>List(3, 6, 9)</td><td>List(extra_value3, value3)</td><td>3</td><td>string3</td></tr></tbody></table></div>

# %% [markdown]
# #### Creating SQL Temporary view on Json files for reading json data.

# %%
# %sql 
CREATE TEMPORARY VIEW emp_json_table
USING json
OPTIONS (path "/FileStore/tables/emp_json.json")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from emp_json_table where sal>1250.0
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COMM</th><th>DEPTNO</th><th>EMPNO</th><th>ENAME</th><th>HIREDATE</th><th>JOB</th><th>MGR</th><th>SAL</th></tr></thead><tbody><tr><td>300</td><td>30</td><td>7499</td><td>ALLEN</td><td>20-02-81</td><td>SALESMAN</td><td>7698</td><td>1600</td></tr><tr><td>null</td><td>20</td><td>7566</td><td>JONES</td><td>02-04-81</td><td>MANAGER</td><td>7839</td><td>2975</td></tr><tr><td>null</td><td>30</td><td>7698</td><td>SGR</td><td>01-05-81</td><td>MANAGER</td><td>7839</td><td>2850</td></tr><tr><td>null</td><td>10</td><td>7782</td><td>RAVI</td><td>09-06-81</td><td>MANAGER</td><td>7839</td><td>2450</td></tr><tr><td>null</td><td>20</td><td>7788</td><td>SCOTT</td><td>19-04-87</td><td>ANALYST</td><td>7566</td><td>3000</td></tr><tr><td>null</td><td>10</td><td>7839</td><td>KING</td><td>17-11-81</td><td>PRESIDENT</td><td>null</td><td>5000</td></tr><tr><td>0</td><td>30</td><td>7844</td><td>TURNER</td><td>08-09-81</td><td>SALESMAN</td><td>7698</td><td>1500</td></tr><tr><td>null</td><td>20</td><td>7902</td><td>FORD</td><td>03-12-81</td><td>ANALYST</td><td>7566</td><td>3000</td></tr><tr><td>null</td><td>10</td><td>7934</td><td>MILLER</td><td>23-01-82</td><td>CLERK</td><td>7782</td><td>1300</td></tr></tbody></table></div>

# %% [markdown]
# ## Multi Line Json File Data...

# %%
dbutils.fs.put("/tmp/multiline.json", """
[
    {"string":"string1","int":1,"array":[1,2,3],"dict": {"key": "value1"}},
    {"string":"string2","int":2,"array":[2,4,6],"dict": {"key": "value2"}},
    {
        "string": "string3",
        "int": 3,
        "array": [
            3,
            6,
            9
        ],
        "dict": {
            "key": "value3",
            "extra_key": "extra_value3"
        }
    }
]""",True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 386 bytes.
# Out[17]: True</div>

# %%
json_data=spark.read.option('multiline',"true").json("/tmp/multiline.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(json_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>array</th><th>dict</th><th>int</th><th>string</th></tr></thead><tbody><tr><td>List(1, 2, 3)</td><td>List(null, value1)</td><td>1</td><td>string1</td></tr><tr><td>List(2, 4, 6)</td><td>List(null, value2)</td><td>2</td><td>string2</td></tr><tr><td>List(3, 6, 9)</td><td>List(extra_value3, value3)</td><td>3</td><td>string3</td></tr></tbody></table></div>

# %%
multi_line_df=spark.read.option("multiline", "true").json("/tmp/multiline.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(multi_line_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>array</th><th>dict</th><th>int</th><th>string</th></tr></thead><tbody><tr><td>List(1, 2, 3)</td><td>List(null, value1)</td><td>1</td><td>string1</td></tr><tr><td>List(2, 4, 6)</td><td>List(null, value2)</td><td>2</td><td>string2</td></tr><tr><td>List(3, 6, 9)</td><td>List(extra_value3, value3)</td><td>3</td><td>string3</td></tr></tbody></table></div>

# %% [markdown]
# *  Creating `RDD` for customised Json Data
# *  Creating `DataFrame` for Customised Json Data
# *  Reading `Nested` `Struct` Fields json data

# %%
# an RDD[String] storing one JSON object per string
my_data = ['{"name":"Ravi","address":{"city":"Bangalore","state":"Karnataka"}}']
my_rdd = sc.parallelize(my_data)
my_df = spark.read.json(my_rdd)
my_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- address: struct (nullable = true)
#     |-- city: string (nullable = true)
#     |-- state: string (nullable = true)
# -- name: string (nullable = true)
#
# </div>

# %%
display(my_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>address</th><th>name</th></tr></thead><tbody><tr><td>List(Bangalore, Karnataka)</td><td>Ravi</td></tr></tbody></table></div>

# %% [markdown]
# * Get individual item and values using select query..

# %%
display(my_df.select("address.city","address.state","name"))
#my_df.select("address.city","address.state","name").show()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>state</th><th>name</th></tr></thead><tbody><tr><td>Bangalore</td><td>Karnataka</td><td>Ravi</td></tr></tbody></table></div>

# %%
stringJSONRDD = sc.parallelize((""" 
  { "id": "123",
    "name": "Raj",
    "age": 39,
    "eyeColor": "brown"
  }""",
   """{
    "id": "234",
    "name": "Srinu",
    "age": 37,
    "eyeColor": "Black"
  }""", 
  """{
    "id": "345",
    "name": "Ravi",
    "age": 35,
    "eyeColor": "red"
  }""")
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_json_df=spark.read.json(stringJSONRDD)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_json_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- age: long (nullable = true)
# -- eyeColor: string (nullable = true)
# -- id: string (nullable = true)
# -- name: string (nullable = true)
#
# </div>

# %%
display(test_json_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>eyeColor</th><th>id</th><th>name</th></tr></thead><tbody><tr><td>39</td><td>brown</td><td>123</td><td>Raj</td></tr><tr><td>37</td><td>Black</td><td>234</td><td>Srinu</td></tr><tr><td>35</td><td>red</td><td>345</td><td>Ravi</td></tr></tbody></table></div>

# %% [markdown]
# ####  Writing Json Files data from DataFrame
# * using `mode('append')` and `mode('overwrite')`

# %%
emp_json.write.mode('append').json('/FileStore/Tables/jsonfiles')
#emp_json.write.mode('overwrite').json('/FileStore/Tables/jsonfiles')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs
ls /FileStore/Tables/jsonfiles/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/Tables/jsonfiles/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/FileStore/Tables/jsonfiles/_committed_2464412959603568780</td><td>_committed_2464412959603568780</td><td>472</td></tr><tr><td>dbfs:/FileStore/Tables/jsonfiles/_committed_5807186400108590717</td><td>_committed_5807186400108590717</td><td>114</td></tr><tr><td>dbfs:/FileStore/Tables/jsonfiles/_committed_6188326100353873665</td><td>_committed_6188326100353873665</td><td>114</td></tr><tr><td>dbfs:/FileStore/Tables/jsonfiles/_committed_6540946452806229999</td><td>_committed_6540946452806229999</td><td>115</td></tr><tr><td>dbfs:/FileStore/Tables/jsonfiles/_committed_vacuum4435709910176646463</td><td>_committed_vacuum4435709910176646463</td><td>162</td></tr><tr><td>dbfs:/FileStore/Tables/jsonfiles/_started_6540946452806229999</td><td>_started_6540946452806229999</td><td>0</td></tr><tr><td>dbfs:/FileStore/Tables/jsonfiles/part-00000-tid-2464412959603568780-ff1ab8fa-1c1b-4eba-bbc5-8fa214c929b5-110-1-c000.json</td><td>part-00000-tid-2464412959603568780-ff1ab8fa-1c1b-4eba-bbc5-8fa214c929b5-110-1-c000.json</td><td>1685</td></tr><tr><td>dbfs:/FileStore/Tables/jsonfiles/part-00000-tid-5807186400108590717-72a56d7e-ec63-422f-8988-89aa286bb907-111-1-c000.json</td><td>part-00000-tid-5807186400108590717-72a56d7e-ec63-422f-8988-89aa286bb907-111-1-c000.json</td><td>1685</td></tr><tr><td>dbfs:/FileStore/Tables/jsonfiles/part-00000-tid-6540946452806229999-9882638c-66fc-48fb-ae14-15cdda6bce0c-5590-1-c000.json</td><td>part-00000-tid-6540946452806229999-9882638c-66fc-48fb-ae14-15cdda6bce0c-5590-1-c000.json</td><td>1685</td></tr></tbody></table></div>

# %% [markdown]
# * install urllib
# #### Install urllib library

# %%
# !pip install urllib
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# * request remote zip file using ```` urllib.request.Request````

# %%
import urllib 
urllib.request.urlretrieve("https://resources.lendingclub.com/LoanStats3a.csv.zip", "/tmp/LoanStats3a.csv.zip")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: (&#39;/tmp/LoanStats3a.csv.zip&#39;, &lt;http.client.HTTPMessage at 0x7f473864dcd0&gt;)</div>

# %%
# %sh
unzip /tmp/LoanStats3a.csv.zip
tail -n +2 LoanStats3a.csv > temp.csv
rm LoanStats3a.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Archive:  /tmp/LoanStats3a.csv.zip
#   inflating: LoanStats3a.csv
# </div>

# %%
# %fs ls file:/databricks/driver/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>file:/databricks/driver/conf/</td><td>conf/</td><td>4096</td></tr><tr><td>file:/databricks/driver/eventlogs/</td><td>eventlogs/</td><td>4096</td></tr><tr><td>file:/databricks/driver/logs/</td><td>logs/</td><td>4096</td></tr><tr><td>file:/databricks/driver/ganglia/</td><td>ganglia/</td><td>4096</td></tr><tr><td>file:/databricks/driver/temp.csv</td><td>temp.csv</td><td>42408085</td></tr><tr><td>file:/databricks/driver/derby.log</td><td>derby.log</td><td>746</td></tr></tbody></table></div>

# %%
dbutils.fs.mv("file:/databricks/driver/temp.csv", "dbfs:/tmp/LoanStats3a.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: True</div>

# %%
df = spark.read.format("csv").option("inferSchema", "true").option("header","true").load("dbfs:/tmp/LoanStats3a.csv")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
import urllib.request
urllib.request.urlretrieve("http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data_10_percent.gz","/tmp/myfile.gz")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: (&#39;/tmp/myfile.gz&#39;, &lt;http.client.HTTPMessage at 0x7f473165ca90&gt;)</div>

# %%
dbutils.fs.mv("file:/tmp/myfile.gz", "dbfs:/tmp/myfile.gz")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: True</div>

# %%
# %fs ls dbfs:/tmp/myfile.gz
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/tmp/myfile.gz</td><td>myfile.gz</td><td>2144903</td></tr></tbody></table></div>

# %%
# %sh
gunzip -r /dbfs/tmp/myfile.gz
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls('dbfs:/tmp/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [FileInfo(path=&#39;dbfs:/tmp/LoanStats3a.csv&#39;, name=&#39;LoanStats3a.csv&#39;, size=42408085),
#  FileInfo(path=&#39;dbfs:/tmp/PySpark_Data/&#39;, name=&#39;PySpark_Data/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/tmp/book.xml&#39;, name=&#39;book.xml&#39;, size=5542),
#  FileInfo(path=&#39;dbfs:/tmp/books.xml&#39;, name=&#39;books.xml&#39;, size=79),
#  FileInfo(path=&#39;dbfs:/tmp/diamons.csv/&#39;, name=&#39;diamons.csv/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/tmp/excel.xlsx&#39;, name=&#39;excel.xlsx&#39;, size=5269),
#  FileInfo(path=&#39;dbfs:/tmp/file.csv/&#39;, name=&#39;file.csv/&#39;, size=0),
# ...

# %%
df = spark.read.format("csv").option("inferSchema", "true").option("header","true").load("/tmp/myfile")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.fs.ls('/FileStore/tables/')

# %%
# %sh
unzip dbfs:/FileStore/tables/emp.zip

# %% [markdown]
# #### reading spark config file

# %%
a=sc.textFile('file:/tmp/custom-spark.conf')
a.collect()

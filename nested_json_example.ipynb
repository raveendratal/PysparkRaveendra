# %%
from pyspark.sql.functions import explode, col
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
source_json = """
{
    "persons": [
        {
            "name": "John",
            "age": 30,
            "cars": [
                {
                    "name": "Ford",
                    "models": [
                        "Fiesta",
                        "Focus",
                        "Mustang"
                    ]
                },
                {
                    "name": "BMW",
                    "models": [
                        "320",
                        "X3",
                        "X5"
                    ]
                }
            ]
        },
        {
            "name": "Peter",
            "age": 46,
            "cars": [
                {
                    "name": "Huyndai",
                    "models": [
                        "i10",
                        "i30"
                    ]
                },
                {
                    "name": "Mercedes",
                    "models": [
                        "E320",
                        "E63 AMG"
                    ]
                }
            ]
        }
    ]
}
"""
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.rm('/FileStore/tables/multiline_nested_json.json')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: True</div>

# %%
dbutils.fs.put('/FileStore/tables/multiline_nested_json.json',source_json)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 1074 bytes.
# Out[21]: True</div>

# %%
source_df = spark.read.option("multiline", "true").json("/FileStore/tables/multiline_nested_json.json")
display(source_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>persons</th></tr></thead><tbody><tr><td>List(List(30, List(List(List(Fiesta, Focus, Mustang), Ford), List(List(320, X3, X5), BMW)), John), List(46, List(List(List(i10, i30), Huyndai), List(List(E320, E63 AMG), Mercedes)), Peter))</td></tr></tbody></table></div>

# %%
# Explode all persons into different rows
persons = source_df.select(explode("persons").alias("persons"))
display(persons)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>persons</th></tr></thead><tbody><tr><td>List(30, List(List(List(Fiesta, Focus, Mustang), Ford), List(List(320, X3, X5), BMW)), John)</td></tr><tr><td>List(46, List(List(List(i10, i30), Huyndai), List(List(E320, E63 AMG), Mercedes)), Peter)</td></tr></tbody></table></div>

# %%
# Explode all car brands into different rows
persons_cars = persons.select(
   col("persons.name").alias("persons_name")
 , col("persons.age").alias("persons_age")
 , explode("persons.cars").alias("persons_cars_brands")
 , col("persons_cars_brands.name").alias("persons_cars_brand")
)
display(persons_cars)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>persons_name</th><th>persons_age</th><th>persons_cars_brands</th><th>persons_cars_brand</th></tr></thead><tbody><tr><td>John</td><td>30</td><td>List(List(Fiesta, Focus, Mustang), Ford)</td><td>Ford</td></tr><tr><td>John</td><td>30</td><td>List(List(320, X3, X5), BMW)</td><td>BMW</td></tr><tr><td>Peter</td><td>46</td><td>List(List(i10, i30), Huyndai)</td><td>Huyndai</td></tr><tr><td>Peter</td><td>46</td><td>List(List(E320, E63 AMG), Mercedes)</td><td>Mercedes</td></tr></tbody></table></div>

# %%
# Explode all car models into different rows
persons_cars_models = persons_cars.select(
   col("persons_name")
 , col("persons_age")
 , col("persons_cars_brand")
 , explode("persons_cars_brands.models").alias("persons_cars_model")
)
display(persons_cars_models)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>persons_name</th><th>persons_age</th><th>persons_cars_brand</th><th>persons_cars_model</th></tr></thead><tbody><tr><td>John</td><td>30</td><td>Ford</td><td>Fiesta</td></tr><tr><td>John</td><td>30</td><td>Ford</td><td>Focus</td></tr><tr><td>John</td><td>30</td><td>Ford</td><td>Mustang</td></tr><tr><td>John</td><td>30</td><td>BMW</td><td>320</td></tr><tr><td>John</td><td>30</td><td>BMW</td><td>X3</td></tr><tr><td>John</td><td>30</td><td>BMW</td><td>X5</td></tr><tr><td>Peter</td><td>46</td><td>Huyndai</td><td>i10</td></tr><tr><td>Peter</td><td>46</td><td>Huyndai</td><td>i30</td></tr><tr><td>Peter</td><td>46</td><td>Mercedes</td><td>E320</td></tr><tr><td>Peter</td><td>46</td><td>Mercedes</td><td>E63 AMG</td></tr></tbody></table></div>

# %%
persons_cars_models.write.format('delta').mode('append').saveAsTable('delta.customer_cars')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from delta.customer_cars
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
